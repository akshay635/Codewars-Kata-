# %% [markdown]
# <a href="https://colab.research.google.com/github/akshay635/Codewars-Kata-/blob/main/EDA_of_Suryakumar_Yadav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA(Exploratory Data Analysis) of Indian Cricketer Suryakumar Yadav

# %% [markdown]
# Importing the useful libraries for data analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Fetching data from csv files using pandas built-in function pd.read_csv

# %%
ipl_ball_data = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022.csv')
ipl_match_data = pd.read_csv('/content/IPL_Matches_2008_2022.csv')

# %% [markdown]
# Displaying the top 5 data from dataset

# %%
ipl_ball_data.head(5)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %% [markdown]
# Collecting data of Cricketer Suryakumar Yadav by filtering the data

# %%
sky_data = ipl_ball_data[ipl_ball_data['batter'] == 'SA Yadav']

# %%
sky_data
# Out:
#              ID  innings  overs  ballnumber    batter       bowler  \
# 5559    1304097        1      7           4  SA Yadav  Rashid Khan
# 5560    1304097        1      7           5  SA Yadav  Rashid Khan
# 5563    1304097        1      8           2  SA Yadav    R Tewatia
# 5566    1304097        1      8           5  SA Yadav    R Tewatia
# 5569    1304097        1      9           2  SA Yadav  LH Ferguson
# ...         ...      ...    ...         ...       ...          ...
# 131282   729279        1     19           6  SA Yadav  CJ Anderson
# 166921   548308        2     10           6  SA Yadav     M Kartik
# 166926   548308        2     11           5  SA Yadav      B Kumar
# 166927   548308        2     11           6  SA Yadav      B Kumar
# 166929   548308        2     12           2  SA Yadav   MN Samuels
#
#          non-striker extra_type  batsman_run  extras_run  total_run  \
# 5559    Ishan Kishan        NaN            0           0          0
# ...

# %% [markdown]
#           Suryakumar Yadav's ball to ball data in IPL from 2008 to 2022

# %%
sky_data['ballnumber'].value_counts()
# Out:
# 4    333
# 1    332
# 3    328
# 2    315
# 5    307
# 6    304
# 7     46
# 8      8
# Name: ballnumber, dtype: int64

# %%
sky_data['ballnumber'].count()
# Out:
# 1973

# %% [markdown]
# Total Number of balls played by Suryakumar Yadav

# %%
sky_data['batsman_run'].sum()
# Out:
# 2644

# %% [markdown]
# Total runs scored by Suryakumar Yadav

# %%
strike_rate = (sky_data['batsman_run'].sum() / sky_data['ballnumber'].count())*100

# %% [markdown]
# Formula to calculate average strike rate of a batsman

# %%
round(strike_rate)
# Out:
# 134

# %% [markdown]
# Average Strike rate of Suryakumar Yadav

# %%
sky_data['batsman_run'].value_counts()
# Out:
# 1    768
# 0    722
# 4    284
# 2    109
# 6     84
# 3      6
# Name: batsman_run, dtype: int64

# %% [markdown]
# 4s-284
#
# 6s-84
#
# 2s-109
#
# 3s-6
#
# 1s-768
#
# 0s-722

# %%
sky_data['isWicketDelivery'].value_counts()
# Out:
# 0    1885
# 1      88
# Name: isWicketDelivery, dtype: int64

# %% [markdown]
# 88 times he has got dismissed in ipl

# %%
d1 = pd.DataFrame(sky_data.groupby(['ID'])['ballnumber'].count())

# %%
d2 = pd.DataFrame(sky_data.groupby(['ID'])['batsman_run'].sum())

# %%
d1
# Out:
#          ballnumber
# ID
# 548308            4
# 729279            5
# 729289            3
# 729299           19
# 729307           18
# ...             ...
# 1304072          29
# 1304079          21
# 1304083           7
# 1304090          39
# 1304097          11
#
# [108 rows x 1 columns]

# %%
d2
# Out:
#          batsman_run
# ID
# 548308             0
# 729279            13
# 729289             8
# 729299            24
# 729307            34
# ...              ...
# 1304072           37
# 1304079           32
# 1304083            7
# 1304090           51
# 1304097           13
#
# [108 rows x 1 columns]

# %%
d3 = pd.merge(d1, d2, how='inner', on = 'ID')

# %% [markdown]
# This d3 dataframe shows match-by-match data of Suryakumar Yadav

# %%
d3
# Out:
#          ballnumber  batsman_run
# ID
# 548308            4            0
# 729279            5           13
# 729289            3            8
# 729299           19           24
# 729307           18           34
# ...             ...          ...
# 1304072          29           37
# 1304079          21           32
# 1304083           7            7
# 1304090          39           51
# 1304097          11           13
#
# [108 rows x 2 columns]

# %% [markdown]
# Adding Strike rate column

# %%
d3['strike_rate'] = (d3['batsman_run']/d3['ballnumber'])*100

# %%
d3
# Out:
#          ballnumber  batsman_run  strike_rate
# ID
# 548308            4            0     0.000000
# 729279            5           13   260.000000
# 729289            3            8   266.666667
# 729299           19           24   126.315789
# 729307           18           34   188.888889
# ...             ...          ...          ...
# 1304072          29           37   127.586207
# 1304079          21           32   152.380952
# 1304083           7            7   100.000000
# 1304090          39           51   130.769231
# 1304097          11           13   118.181818
#
# [108 rows x 3 columns]

# %% [markdown]
# This is the final dataframe showing runs scored by SA Yadav in each innings along with balls faced and strike rate

# %%
len(d3)
# Out:
# 108

# %% [markdown]
# Total no. of Innings played by Suryakumar Yadav

# %%
not_outs = len(d3) - 88

# %%
not_outs
# Out:
# 20

# %% [markdown]
# 20 times he remained as not out.

# %%
d3['ballnumber'].sum()
# Out:
# 1973

# %% [markdown]
# Total No of balls played by Suryakumar Yadav

# %%
d3['batsman_run'].sum()
# Out:
# 2644

# %% [markdown]
# Total runs scored by Suryakumar Yadav in IPL

# %%
average = d3['batsman_run'].sum()/len(d3)

# %% [markdown]
# Formula for calculating batting average of a batsman

# %%
round(average)
# Out:
# 24

# %% [markdown]
# Batting Average of Suryakumar Yadav in IPL

# %%
sr_sky = (d3['batsman_run'].sum() / d3['ballnumber'].sum())*100

# %%
sr_sky
# Out:
# 134.0091231626964

# %%
second_inn = sky_data[sky_data['innings'] == 2]

# %%
second_inn
# Out:
#              ID  innings  overs  ballnumber    batter             bowler  \
# 7382    1304090        2      2           4  SA Yadav           R Ashwin
# 7385    1304090        2      3           1  SA Yadav  M Prasidh Krishna
# 7386    1304090        2      3           2  SA Yadav  M Prasidh Krishna
# 7387    1304090        2      3           3  SA Yadav  M Prasidh Krishna
# 7388    1304090        2      3           4  SA Yadav  M Prasidh Krishna
# ...         ...      ...    ...         ...       ...                ...
# 128102   729307        2     17           3  SA Yadav     Sandeep Sharma
# 166921   548308        2     10           6  SA Yadav           M Kartik
# 166926   548308        2     11           5  SA Yadav            B Kumar
# 166927   548308        2     11           6  SA Yadav            B Kumar
# 166929   548308        2     12           2  SA Yadav         MN Samuels
#
#          non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
df1 = pd.DataFrame(second_inn.groupby(['ID'])['batsman_run'].sum())

# %%
df1
# Out:
#          batsman_run
# ID
# 548308             0
# 729307            34
# 729315            31
# 733971             8
# 733979             9
# 734037            12
# 734049             5
# 829705            46
# 829723             2
# 829733            23
# 829739            24
# 829743             2
# 829765            16
# 829791             9
# 829805            11
# 829811             0
# 980925            11
# 980939            60
# 980951            21
# 980959            10
# 981015            23
# 1082608            7
# 1136583           34
# 1136587           44
# 1136591            9
# 1136594           57
# 1136615           12
# 1175358            2
# 1178399           21
# 1178406           29
# 1178422           26
# 1178431           46
# 1181764           71
# 1216499           79
# 1216526           10
# 1216529           53
# 1216535           12
# 1216547            0
# 1237181           19
# 1254081           16
# 1254084            3
# 1254093           13
# ...

# %%
df2 = pd.DataFrame(second_inn.groupby(['ID'])['ballnumber'].count())

# %%
df2
# Out:
#          ballnumber
# ID
# 548308            4
# 729307           18
# 729315           20
# 733971           13
# 733979           18
# 734037            6
# 734049            6
# 829705           21
# 829723            3
# 829733           10
# 829739           17
# 829743            2
# 829765           26
# 829791            9
# 829805            5
# 829811            1
# 980925            9
# 980939           54
# 980951           13
# 980959            5
# 981015           15
# 1082608           9
# 1136583          39
# 1136587          35
# 1136591           9
# 1136594          42
# 1136615           4
# 1175358           6
# 1178399          15
# 1178406          23
# 1178422          14
# 1178431          28
# 1181764          54
# 1216499          44
# 1216526          10
# 1216529          33
# 1216535          11
# 1216547           2
# 1237181          20
# 1254081          10
# 1254084           3
# 1254093           9
# 1254099           1
# 1254104           7
# ...

# %%
df3 = pd.merge(df1, df2,how = "inner", on = 'ID')

# %%
df3
# Out:
#          batsman_run  ballnumber
# ID
# 548308             0           4
# 729307            34          18
# 729315            31          20
# 733971             8          13
# 733979             9          18
# 734037            12           6
# 734049             5           6
# 829705            46          21
# 829723             2           3
# 829733            23          10
# 829739            24          17
# 829743             2           2
# 829765            16          26
# 829791             9           9
# 829805            11           5
# 829811             0           1
# 980925            11           9
# 980939            60          54
# 980951            21          13
# 980959            10           5
# 981015            23          15
# 1082608            7           9
# 1136583           34          39
# 1136587           44          35
# 1136591            9           9
# 1136594           57          42
# 1136615           12           4
# ...

# %%
len(df3)
# Out:
# 49

# %% [markdown]
# No of matches in which he batted in 2nd Innings.

# %%
df3['strike_rate'] = (df3['batsman_run'] / df3['ballnumber'])*100

# %%
df3
# Out:
#          batsman_run  ballnumber  strike_rate
# ID
# 548308             0           4     0.000000
# 729307            34          18   188.888889
# 729315            31          20   155.000000
# 733971             8          13    61.538462
# 733979             9          18    50.000000
# 734037            12           6   200.000000
# 734049             5           6    83.333333
# 829705            46          21   219.047619
# 829723             2           3    66.666667
# 829733            23          10   230.000000
# 829739            24          17   141.176471
# 829743             2           2   100.000000
# 829765            16          26    61.538462
# 829791             9           9   100.000000
# 829805            11           5   220.000000
# 829811             0           1     0.000000
# 980925            11           9   122.222222
# 980939            60          54   111.111111
# 980951            21          13   161.538462
# ...

# %% [markdown]
# Second Innings data with runs, balls faced and strike rate per inning

# %%
df3['batsman_run'].sum()
# Out:
# 1069

# %% [markdown]
# Total Runs scored by him in Second innings

# %%
df3['ballnumber'].sum()
# Out:
# 817

# %% [markdown]
# Total no of balls played by him in second innings

# %%
str_rate_2nd_inn = (df3['batsman_run'].sum() / df3['ballnumber'].sum())*100

# %%
round(str_rate_2nd_inn)
# Out:
# 131

# %% [markdown]
# His Strike rate in Second Innings

# %%
average_second_inn = df3['batsman_run'].sum() / len(df3)

# %%
round(average_second_inn)
# Out:
# 22

# %% [markdown]
# His batting average in 2nd Innings

# %%
second_inn['isWicketDelivery'].value_counts()
# Out:
# 0    778
# 1     39
# Name: isWicketDelivery, dtype: int64

# %% [markdown]
# 39 times he got dismissed in 2nd Innings

# %%
first_inn = sky_data[sky_data['innings']==1]

# %%
first_inn
# Out:
#              ID  innings  overs  ballnumber    batter       bowler  \
# 5559    1304097        1      7           4  SA Yadav  Rashid Khan
# 5560    1304097        1      7           5  SA Yadav  Rashid Khan
# 5563    1304097        1      8           2  SA Yadav    R Tewatia
# 5566    1304097        1      8           5  SA Yadav    R Tewatia
# 5569    1304097        1      9           2  SA Yadav  LH Ferguson
# ...         ...      ...    ...         ...       ...          ...
# 131277   729279        1     19           1  SA Yadav  CJ Anderson
# 131279   729279        1     19           3  SA Yadav  CJ Anderson
# 131280   729279        1     19           4  SA Yadav  CJ Anderson
# 131281   729279        1     19           5  SA Yadav  CJ Anderson
# 131282   729279        1     19           6  SA Yadav  CJ Anderson
#
#          non-striker extra_type  batsman_run  extras_run  total_run  \
# 5559    Ishan Kishan        NaN            0           0          0
# ...

# %%
first_inn['isWicketDelivery'].value_counts()
# Out:
# 0    1107
# 1      48
# Name: isWicketDelivery, dtype: int64

# %% [markdown]
# 48 times he got dismissed in 1st Innings

# %%
df4 = pd.DataFrame(first_inn.groupby(['ID'])['batsman_run'].sum())

# %%
df5 = pd.DataFrame(first_inn.groupby(['ID'])['ballnumber'].count())

# %%
df6 = pd.merge(df5,df4, how = 'inner', on = 'ID')

# %%
df4
# Out:
#          batsman_run
# ID
# 729279            13
# 729289             8
# 729299            24
# 734043            20
# 829713            11
# 829761             7
# 829771             0
# 829781             6
# 980909             4
# 980947            21
# 980975             4
# 980995             5
# 981001            17
# 981009             6
# 1082597           17
# 1082604            4
# 1082613            1
# 1082617           15
# 1082631           30
# 1082649           31
# 1136561           43
# 1136567           28
# 1136569           53
# 1136574            0
# 1136581           72
# 1136597           59
# 1136601           36
# 1136607           38
# 1136610           27
# 1175362           38
# 1175364           11
# 1175370           59
# 1178394            7
# 1178402           16
# 1178409           26
# 1178411           34
# 1178426           23
# 1181768           15
# 1216492           17
# 1216495           36
# 1216503           10
# 1216508           47
# ...

# %%
df5
# Out:
#          ballnumber
# ID
# 729279            5
# 729289            3
# 729299           19
# 734043           14
# 829713            9
# 829761            7
# 829771            2
# 829781            3
# 980909            1
# 980947           17
# 980975           12
# 980995            5
# 981001           14
# 981009            3
# 1082597          15
# 1082604           3
# 1082613           1
# 1082617          19
# 1082631          16
# 1082649          26
# 1136561          29
# 1136567          31
# 1136569          32
# 1136574           1
# 1136581          50
# 1136597          40
# 1136601          32
# 1136607          32
# 1136610          15
# 1175362          25
# 1175364           6
# 1175370          43
# 1178394           8
# 1178402          10
# 1178409          27
# 1178411          34
# 1178426          17
# 1181768          17
# 1216492          18
# 1216495          29
# 1216503           7
# 1216508          28
# 1216511          49
# 1216517           4
# ...

# %%
df6
# Out:
#          ballnumber  batsman_run
# ID
# 729279            5           13
# 729289            3            8
# 729299           19           24
# 734043           14           20
# 829713            9           11
# 829761            7            7
# 829771            2            0
# 829781            3            6
# 980909            1            4
# 980947           17           21
# 980975           12            4
# 980995            5            5
# 981001           14           17
# 981009            3            6
# 1082597          15           17
# 1082604           3            4
# 1082613           1            1
# 1082617          19           15
# 1082631          16           30
# 1082649          26           31
# 1136561          29           43
# 1136567          31           28
# 1136569          32           53
# 1136574           1            0
# 1136581          50           72
# 1136597          40           59
# 1136601          32           36
# ...

# %%
df6['strike_rate'] = (df6['batsman_run'] / df6['ballnumber'])*100

# %%
df6
# Out:
#          ballnumber  batsman_run  strike_rate
# ID
# 729279            5           13   260.000000
# 729289            3            8   266.666667
# 729299           19           24   126.315789
# 734043           14           20   142.857143
# 829713            9           11   122.222222
# 829761            7            7   100.000000
# 829771            2            0     0.000000
# 829781            3            6   200.000000
# 980909            1            4   400.000000
# 980947           17           21   123.529412
# 980975           12            4    33.333333
# 980995            5            5   100.000000
# 981001           14           17   121.428571
# 981009            3            6   200.000000
# 1082597          15           17   113.333333
# 1082604           3            4   133.333333
# 1082613           1            1   100.000000
# 1082617          19           15    78.947368
# 1082631          16           30   187.500000
# ...

# %% [markdown]
# His 1st innings data which includes runs scored, balls faced and strike rate per inning.

# %%
df6['batsman_run'].sum()
# Out:
# 1575

# %% [markdown]
# Total runs scored by him in 1st Innings

# %%
len(df6)
# Out:
# 59

# %% [markdown]
# Total no. of matches in which he played in 1st innings

# %%
df6['ballnumber'].sum()
# Out:
# 1155

# %% [markdown]
# Total no. of balls played by him in 1st inn.

# %%
str_rate_1st_inn = (df6['batsman_run'].sum() / df6['ballnumber'].sum())*100

# %%
round(str_rate_1st_inn)
# Out:
# 136

# %% [markdown]
# His batting strike rate in 1st innings

# %%
average_first_inn = df6['batsman_run'].sum() / len(df6)

# %%
round(average_first_inn)
# Out:
# 27

# %% [markdown]
# His batting average in 1st innings

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df3)

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=df3)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data=df6)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data=df3)

# %%
plt.figure(figsize=(15,8))
sns.boxenplot(data=df3)

# %%
plt.figure(figsize=(15,8))
plt.bar(df3['ballnumber'], df3['batsman_run'], label="2nd Innings", color='b')
plt.plot()

plt.xlabel("ball_number")
plt.ylabel("batsman_run")
plt.title("Bar Chart Example")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df6['ballnumber'], df6['batsman_run'] , label="1st Innings", color='g')
plt.plot()

plt.xlabel("ball_number")
plt.ylabel("batsman_run")
plt.title("Bar Chart Example")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxenplot(df3['ballnumber'], df3['batsman_run'],linewidth=1)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,10))
sns.boxenplot(df3['ballnumber'], df3['strike_rate'],linewidth=1)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
